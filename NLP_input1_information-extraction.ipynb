# %%
# Import libraries
import spacy
# !pip install pdfminer.six
from pdfminer.high_level import extract_text

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Define pdf file path
pdf_file = "C:/Users/hp/Downloads/climate_change.pdf"

# Extract text from pdf file
text = extract_text(pdf_file)

# Create a spaCy object from the text
doc = nlp(text)

# Loop through the entities in the doc object
for ent in doc.ents:
  # Print the text and label of each entity
  print(ent.text, ent.label_)
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer.six-20221105-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from pdfminer.six) (2.0.4)
# Collecting cryptography>=36.0.0
#   Downloading cryptography-40.0.2-cp36-abi3-win_amd64.whl (2.6 MB)
# Requirement already satisfied: cffi>=1.12 in c:\users\hp\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.21)
# Installing collected packages: cryptography, pdfminer.six
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 3.4.8
#     Uninstalling cryptography-3.4.8:
#       Successfully uninstalled cryptography-3.4.8
# Successfully installed cryptography-40.0.2 pdfminer.six-20221105
# Climate Finance ORG
# Developed Countries ORG
# 2013-2020 DATE
# Climate Finance ORG
# the USD 100 Billion Goal LAW
# 2013-2020 DATE
# OECD ORG
# OECD ORG
# Israel GPE
# Israeli NORP
# OECD ORG
# the Golan Heights LOC
# East Jerusalem GPE
# Israeli NORP
# the West Bank GPE
# the Republic of Türkiye GPE
# Turkish NORP
# Greek Cypriot NORP
# Türkiye GPE
# the Turkish Republic of Northern Cyprus GPE
# the United Nations ORG
# Türkiye GPE
# European Union ORG
# States GPE
# OECD ORG
# the European Union ORG
# The Republic of Cyprus GPE
# the United Nations ORG
# Türkiye LOC
# the
# Government of the Republic of Cyprus ORG
# OECD ORG
# 2022 DATE
# Aggregate ORG
# Climate Finance Provided ORG
# 2013-2020 DATE
# OECD ORG
# 2 CARDINAL
# Context GPE
# 15th ORDINAL
# UNFCCC ORG
# Copenhagen ORG
# 2009 DATE
# 100  billion MONEY
# 2020 DATE
# UNFCCC ORG
# Cancun  Agreements PERSON
# Cancun PERSON
# 2010[2 CARDINAL
# Paris GPE
# 2025 DATE
# UNFCCC ORG
# 2015[3 CARDINAL
# 2015 DATE
# OECD ORG
# the Paris Agreement ORG
# UNFCCC ORG
# 2018[4 CARDINAL
# OECD ORG
# four CARDINAL
# 1 CARDINAL
# 2020 DATE
# 2013-2019 DATE
# OECD ORG
# 2021[5 CARDINAL
# September 2022 DATE
# OECD ORG
# Development  Co-operation
# Directorates ORG
# 2020 DATE
# OECD ORG
# Agriculture
# Directorate ORG
# 2019-2020 DATE
# UNFCCC ORG
# 2022 DATE
# 1 CARDINAL
# one CARDINAL
# four CARDINAL
# Annex A. PERSON
# 2 CARDINAL
# 2013-2019 DATE
# OECD ORG
# Progress WORK_OF_ART
# Climate ORG
# Annex A. Data PERSON
# 1 CARDINAL
# 2013-2020 DATE
# 2 CARDINAL
# 2016-2020 DATE
# 3 CARDINAL
# 2016-2020 DATE
# 4 CARDINAL
# 2016-2020 DATE
# 5 CARDINAL
# 2016-2020 DATE
# 6 CARDINAL
# 2016-2020 DATE
# 2013-2020 DATE
# 3 CARDINAL
# 2 CARDINAL
# 4 CARDINAL
# 5 CARDINAL
# 7 CARDINAL
# 8 CARDINAL
# 9 CARDINAL
# 12 CARDINAL
# 20 CARDINAL
# 5 CARDINAL
# 7 CARDINAL
# 8 CARDINAL
# 9 CARDINAL
# 10 CARDINAL
# 11 CARDINAL
# 6 CARDINAL
# OECD ORG
# 2022 DATE
# 4 CARDINAL
# Aggregate ORG
# annual DATE
# 2013-2020 DATE
# 2016-2020 DATE
# USD 83.3 billion MONEY
# 2020 DATE
# Asia LOC
# OECD ORG
# 2022 CARDINAL
# 5 CARDINAL
# 2020 DATE
# the initial target year DATE
# UNFCCC ORG
# 83.3  billion MONEY
# 4% PERCENT
# 2019 DATE
# USD 16.7 billion MONEY
# 80% PERCENT
# 2013 DATE
# 2020 DATE
# 38  billion MONEY
# USD PRODUCT
# 68.3  billion MONEY
# year DATE
# 2015 DATE
# 138% PERCENT
# between 2013 and 2020 DATE
# 40% PERCENT
# the same period DATE
# 2016 DATE
# 1.1 CARDINAL
# close to 30% PERCENT
# 2016-2020 DATE
# 19% PERCENT
# 2013-2020 DATE
# year-on-year DATE
# recent years DATE
# 2020 DATE
# 2019 DATE
# 1 CARDINAL
# 2013-2020 DATE
# 2015 DATE
# 2016-20 DATE
# 2013 DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# OECD ORG
# 6 CARDINAL
# Table 1 PRODUCT
# 2013-2020 DATE
# USD billion MONEY
# 1 CARDINAL
# 2 CARDINAL
# Climate ORG
# 3 CARDINAL
# 1+2+3 DATE
# 4 CARDINAL
# Grand Total ORG
# 1+2+3+4 DATE
# 2013 DATE
# 22.5 CARDINAL
# 15.5 CARDINAL
# 13.0 CARDINAL
# 2.2 CARDINAL
# 0.3 CARDINAL
# 38.0 CARDINAL
# 1.6 CARDINAL
# 39.5 CARDINAL
# 12.8 CARDINAL
# 6.5 CARDINAL
# 6.2 CARDINAL
# 52.4 CARDINAL
# 2014 DATE
# 23.1 CARDINAL
# 20.4 CARDINAL
# 18.0 CARDINAL
# 2.0 CARDINAL
# 0.4 CARDINAL
# 43.5 CARDINAL
# 1.6 CARDINAL
# 45.1 CARDINAL
# 16.7 CARDINAL
# 8.1 CARDINAL
# 8.6 CARDINAL
# 61.8 CARDINAL
# 2015 DATE
# 25.9 CARDINAL
# 16.2 CARDINAL
# 14.4 CARDINAL
# 1.4 CARDINAL
# 0.4 CARDINAL
# 42.1 CARDINAL
# 2.5 CARDINAL
# 44.6 CARDINAL
# 2016 DATE
# 28.0 CARDINAL
# 18.9 CARDINAL
# 15.7 CARDINAL
# 2.6 CARDINAL
# 0.6 CARDINAL
# 46.9 CARDINAL
# 1.5 CARDINAL
# 48.5 CARDINAL
# 10.1 CARDINAL
# 5.2 CARDINAL
# 4.9 CARDINAL
# 58.5 CARDINAL
# 2017 DATE
# 27.0 CARDINAL
# 27.1 CARDINAL
# 23.8 CARDINAL
# 2.9 CARDINAL
# 0.5 CARDINAL
# 54.1 CARDINAL
# 3.0 CARDINAL
# 57.1 CARDINAL
# 14.5 CARDINAL
# 4.0 CARDINAL
# 10.5 CARDINAL
# 71.6 CARDINAL
# 2018 DATE
# 32.0 CARDINAL
# 30.5 CARDINAL
# 26.7 CARDINAL
# 3.5 CARDINAL
# 0.3 CARDINAL
# 62.1 CARDINAL
# 2.7 CARDINAL
# 64.8 CARDINAL
# 14.7 CARDINAL
# 3.8 CARDINAL
# 11.0 CARDINAL
# 79.9 CARDINAL
# 2019 DATE
# 28.7 CARDINAL
# 34.7 CARDINAL
# 30.5 CARDINAL
# 3.8 CARDINAL
# 0.3 CARDINAL
# 63.4 CARDINAL
# 2.6 CARDINAL
# 66 CARDINAL
# 14.4 CARDINAL
# 5.8 CARDINAL
# 8.6 CARDINAL
# 80.4 CARDINAL
# 2020 DATE
# 31.4 CARDINAL
# 36.9 CARDINAL
# 33.2 CARDINAL
# 3.5 CARDINAL
# 0.2 CARDINAL
# 68.3 CARDINAL
# 1.9 CARDINAL
# 70.2 CARDINAL
# 13.1 CARDINAL
# 5.1 CARDINAL
# 8.0 CARDINAL
# 83.3 CARDINAL
# 2015 DATE
# 2016-20 DATE
# 2013 DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# COVID-19 ORG
# the USD 100 billion LAW
# between 2019 and DATE
# 2020 DATE
# 4% PERCENT
# 2018 DATE
# 2019 DATE
# 1% PERCENT
# OECD ORG
# 2020[6 CARDINAL
# OECD 2022
#
#
#
#
#
#
#       | ORG
# 2016-2020 DATE
# between 2019 and 2020 DATE
# USD 8.3 billion MONEY
# 41% PERCENT
# USD 2.8 billion MONEY
# 5%).3 CARDINAL
# 2020 DATE
# 58% PERCENT
# Between 2016 and 2020 DATE
# two CARDINAL
# close to half CARDINAL
# 46% PERCENT
# 17% PERCENT
# 2 CARDINAL
# 2016-2020 DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# 3 Year-on-year DATE
# OECD 2022 ORG
# 8 CARDINAL
# previous years DATE
# 2020 DATE
# 71% PERCENT
# USD 48.6 billion MONEY
# 26% PERCENT
# USD 17.9
# billion MONEY
# Between 2016 and 2020 DATE
# USD 5.6 billion MONEY
# 46% PERCENT
# USD 15.3 billion MONEY
# 46% PERCENT
# 3 CARDINAL
# 2016-2020 DATE
# UNFCCC ORG
# OECD ORG
# DAC ORG
# OECD ORG
# 2016-2020 DATE
# 43% PERCENT
# Guarantees ORG
# second ORDINAL
# 19% PERCENT
# year DATE
# year DATE
# OECD ORG
# 2022 CARDINAL
# 9 CARDINAL
# 2016-2020 DATE
# Asia LOC
# 42% PERCENT
# Africa LOC
# 26% PERCENT
# Americas LOC
# 17% PERCENT
# Europe LOC
# 5% PERCENT
# Oceania LOC
# 1% PERCENT
# 4 CARDINAL
# 43% PERCENT
# 2016-2020 DATE
# 27% PERCENT
# 8% PERCENT
# 3% PERCENT
# 4 CARDINAL
# 2016-2020 DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# 4 CARDINAL
# 2.4 CARDINAL
# OECD ORG
# 2021[5 CARDINAL
# Europe LOC
# Non-EU/EEA Europe ORG
# OECD ORG
# 2022 DATE
# 10 CARDINAL
# Between 2016 and 2020 DATE
# 10 CARDINAL
# 58% PERCENT
# 34% PERCENT
# 50% PERCENT
# 20 CARDINAL
# 74% PERCENT
# 5 CARDINAL
# 2016-2020 DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# OECD ORG
# 2022 CARDINAL
# 11 CARDINAL
# Between 2016 and 2020 DATE
# 40 CARDINAL
# 46 CARDINAL
# 57 CARDINAL
# states5 ORG
# 2% PERCENT
# 17% PERCENT
# 22% PERCENT
# mobilised6 GPE
# 7 CARDINAL
# USD 81 DATE
# USD 14 LAW
# USD 21 PRODUCT
# 6 CARDINAL
# 2016-2020 DATE
# annual DATE
# UNFCCC ORG
# OECD DAC and Export Credit Group ORG
# OECD ORG
# 5 CARDINAL
# OECD ORG
# OECD ORG
# 6 CARDINAL
# three CARDINAL
# 7 CARDINAL
# 1700 DATE
# 2016-2020 DATE
# OECD 2022 ORG
# 12 CARDINAL
# Annex A. Data PERSON
# OECD ORG
# 2015 DATE
# first ORDINAL
# 2013-2014 DATE
# OECD ORG
# OECD ORG
# 2020[6 CARDINAL
# OECD ORG
# 2021[5 CARDINAL
# 2017 DATE
# 2018 DATE
# 2019 DATE
# UNFCCC ORG
# the Paris Agreement LAW
# UNFCCC ORG
# 2018[4 CARDINAL
# four CARDINAL
# OECD ORG
# DAC ORG
# OECD ECG ORG
# UNFCCC ORG
# OECD 2022
#
#
# Figure A.1 ORG
# 13 CARDINAL
# OECD ORG
# 2020[6 CARDINAL
# Mobilised PERSON
# Climate ORG
# Instruments
# Grants PRODUCT
# USA GPE
# Biennial DATE
# UNFCCC ORG
# Grants PRODUCT
# OECD Development Assistance
#
# Export ORG
# annual DATE
# OECD Export Credit Group ORG
# OECD Development Assistance
# Committee ORG
# CTF ORG
# Annex I Parties’  Biennial Reports WORK_OF_ART
# UNFCCC ORG
# 2019 DATE
# 2022 DATE
# fifth ORDINAL
# 2019 DATE
# OECD ORG
# 14 CARDINAL
# States GPE
# the European Union ORG
# annually DATE
# European
# Commission ORG
# the EU Monitoring Mechanism Regulation ORG
# the European Union ORG
# OECD ORG
# UNFCCC ORG
# United  States GPE
# OECD ORG
# GCF ORG
# CTF ORG
# UNFCCC ORG
# OECD ORG
# OECD ORG
# DAC ORG
# UNFCCC ORG
# OECD  Export  Credit  Group’s ORG
# ECG ORG
# ECG ORG
# two CARDINAL
# ECG ORG
# two years DATE
# the Arrangement on Officially Supported Export Credits ORG
# OECD ORG
# Arrangement PRODUCT
# ECG ORG
# OECD ORG
# biennial DATE
# UNFCCC ORG
# OECD ORG
# 2022 CARDINAL
# 15 CARDINAL
# UNFCCC ORG
# one CARDINAL
# OECD ORG
# OECD ORG
# OECD ORG
# 2021[9 CARDINAL
# OECD ORG
# DAC ORG
# 2017 DATE
# OECD ORG
# DAC ORG
# the Statistical Reporting Directives ORG
# CRS ORG
# OECD ORG
# 2021[10 CARDINAL
# The Working Party on Development Finance Statistics ORG
# OECD ORG
# OECD ORG
# 2016, 2017 DATE
# 2018 DATE
# OECD ORG
# DAC ORG
# OECD DAC ORG
# the year 2019 DATE
# annual DATE
# OECD ORG
# DAC ORG
# OECD ORG
# 2015[11 CARDINAL
# OECD 2022 ORG
# 16 CARDINAL
# Table A.2 PRODUCT
# Institution ORG
# 2015 DATE
# 2018 DATE
# 2020 DATE
# African Development Bank ORG
# African Development Fund ORG
# Asian Development Bank ORG
# Asian Development Bank Special Fund ORG
# Asian Development Bank Credit Guarantee ORG
# Development Bank ORG
# Central American Bank for Economic Integration
# Council of Europe Development Bank
# Development Bank of Latin America ORG
# European Bank for Reconstruction and Development
# European Investment Bank
# International Bank for Reconstruction and Development
# International Development Association ORG
# Inter-American Development Bank ORG
# Inter-American Development Bank Special Fund ORG
# IDB Invest
# International Finance Corporation ORG
# International Investment Bank ORG
# Multilateral Investment Guarantee Agency ORG
# North American Development Bank
# Private Infrastructure Development Group
# Adaptation Fund ORG
# Global Environment Facility Trust Funds ORG
# Global Environment Facility Least Developed Countries Fund
# Global Environment Facility Special Climate Change Fund ORG
# Green Climate Fund
# International Fund for Agricultural Development
# Nordic Development Fund ORG
# AfDF ORG
# AsDB LOC
# AsDF NORP
# CDB ORG
# COEB ORG
# CAF ORG
# EBRD ORG
# EIB ORG
# IDA ORG
# NADB ORG
# GEF ORG
# GEF ORG
# LDCF PRODUCT
# GEF SCCF ORG
# GCF ORG
# IFAD GPE
# NDF ORG
# 59.0% PERCENT
# 94.0% PERCENT
# 71.0% PERCENT
# 96.0% PERCENT
# N/A
#  ORG
# 89.0% PERCENT
# 99.0% PERCENT
# 70.0% PERCENT
# 95.0% PERCENT
# 74.0% PERCENT
# 73.0% PERCENT
# 64.1% PERCENT
# N/A
#  ORG
# 64.3% PERCENT
# N/A
# N/A ORG
# 100.0% PERCENT
# 100.0% PERCENT
# 98.0% PERCENT
# 100.0% PERCENT
# 100.0% PERCENT
# 100.0% PERCENT
# 56.4% PERCENT
# 93.6% PERCENT
# 71.4% PERCENT
# 95.2% PERCENT
# N/A
#  ORG
# 27.3% PERCENT
# N/A ORG
# 34.6% PERCENT
# N/A
#  ORG
# 93.7% PERCENT
# 4.6% PERCENT
# 91.4% PERCENT
# 100.0% PERCENT
# 69.9% PERCENT
# 95.9% PERCENT
# 73.6% PERCENT
# 72.5% PERCENT
# 33.6% PERCENT
# 65.4% PERCENT
# 52.2% PERCENT
# 66.1% PERCENT
# N/A ORG
# 99.5% PERCENT
# 100.0% PERCENT
# 99.0% PERCENT
# 98.0% PERCENT
# 100.0% PERCENT
# 100.0% PERCENT
# 99.6% PERCENT
# 74.2% PERCENT
# 100.0% PERCENT
# 61.2% PERCENT
# 93.4% PERCENT
# 71.6% PERCENT
# N/A ORG
# 42.8% PERCENT
# 28.6% PERCENT
# 44.2% PERCENT
# 34.6% PERCENT
# 5.2% PERCENT
# 93.7% PERCENT
# 4.8% PERCENT
# 91.4% PERCENT
# 100.0% PERCENT
# 71.3% PERCENT
# 95.9% PERCENT
# 73.9% PERCENT
# N/A ORG
# 34.4% PERCENT
# 65.4% PERCENT
# 51.7% PERCENT
# 66.2% PERCENT
# 63.2% PERCENT
# 99.5% PERCENT
# 100.0% PERCENT
# 99.9% PERCENT
# 97.6% PERCENT
# 100.0% PERCENT
# 100.0% PERCENT
# 99.0% PERCENT
# 71.0% PERCENT
# 100.0% PERCENT
# Multilateral
# Development
# Banks
#
# Multilateral
# Climate Funds
#
# Notes: ORG
# 2015 DATE
# 2013 DATE
# 2014 DATE
# 2015 DATE
# 2018 DATE
# 2016 DATE
# 2017 DATE
# 2018 DATE
# 2020 to 2020 DATE
# AsDB LOC
# AsDF NORP
# the start of 2017 DATE
# GCF ORG
# the IDB Invest ORG
# Inter-American Investment Corporation ORG
# IIC ORG
# AIIB ORG
# first ORDINAL
# OECD ORG
# DAC ORG
# 2015 DATE
# 2016 DATE
# 2017 DATE
# IFAD GPE
# CEB GPE
# CAF ORG
# first ORDINAL
# 2018 DATE
# NADB ORG
# 2020 DATE
# OECD ORG
# annual DATE
# 2015[11 CARDINAL
# 2018 DATE
# OECD ORG
# 2020[13 CARDINAL
# UNFCCC ORG
# 2018[14 CARDINAL
# OECD ORG
# Annex II PRODUCT
# European Union ORG
# Lichtenstein GPE
# Monaco PERSON
# the Russian Federation GPE
# Russia GPE
# 17 CARDINAL
# Afghanistan GPE
# Albania GPE
# Algeria GPE
# Angola GPE
# Barbuda PERSON
# Argentina GPE
# Armenia GPE
# Azerbaijan GPE
# Bangladesh GPE
# Bhutan GPE
# Bosnia and GPE
# Botswana GPE
# Brazil GPE
# Burkina Faso PERSON
# Burundi GPE
# Cabo Verde PERSON
# Cambodia GPE
# Chad GPE
# China GPE
# Colombia GPE
# Comoros GPE
# Congo GPE
# Costa Rica GPE
# Côte d'Ivoire FAC
# Cuba GPE
# Korea GPE
# Congo GPE
# Djibouti GPE
# Dominican Republic GPE
# Ecuador GPE
# Egypt GPE
# El Salvador GPE
# Equatorial Guinea GPE
# Eritrea GPE
# Eswatini ORG
# Ethiopia GPE
# Fiji GPE
# Gambia GPE
# Georgia GPE
# Ghana GPE
# Grenada GPE
# Guatemala GPE
# Guinea GPE
# Guinea-Bissau FAC
# Guyana GPE
# Honduras GPE
# India GPE
# Indonesia GPE
# Iran GPE
# Iraq GPE
# Jamaica GPE
# Jordan GPE
# Kazakhstan GPE
# Kenya GPE
# Kiribati GPE
# Kyrgyzstan GPE
# Lao People’s Democratic Republic ORG
# Lebanon GPE
# Lesotho ORG
# Liberia GPE
# Libya GPE
# Madagascar GPE
# Malawi PERSON
# Malaysia GPE
# Maldives GPE
# Mali PERSON
# Mauritania GPE
# Mexico GPE
# Micronesia GPE
# Moldova GPE
# Mongolia GPE
# Montenegro GPE
# Morocco GPE
# Myanmar GPE
# Namibia GPE
# Nauru GPE
# Nepal GPE
# Nicaragua GPE
# North Macedonia GPE
# Pakistan GPE
# Palau GPE
# Panama GPE
# Papua New Guinea GPE
# Paraguay ORG
# Peru GPE
# Philippines GPE
# Rwanda GPE
# Saint Lucia PERSON
# Saint Vincent GPE
# Principe PRODUCT
# Serbia GPE
# Sierra Leone ORG
# Solomon Islands GPE
# Somalia GPE
# South Africa GPE
# South Sudan GPE
# Sri Lanka GPE
# Sudan GPE
# Syrian NORP
# Tajikistan NORP
# Tanzania GPE
# Thailand GPE
# Timor GPE
# Tonga GPE
# Tunisia GPE
# Turkmenistan GPE
# Tuvalu GPE
# Uganda GPE
# Uzbekistan GPE
# Vanuatu GPE
# Venezuela GPE
# Viet Nam GPE
# West Bank GPE
# Gaza Strip GPE
# Yemen GPE
# Zambia GPE
# Zimbabwe GPE
# Bahamas GPE
# Bahrain GPE
# Chile GPE
# Israel GPE
# Kuwait GPE
# Oman GPE
# Qatar GPE
# Korea GPE
# San Marino GPE
# Saudi Arabia GPE
# Seychelles GPE
# Singapore GPE
# Saint Kitts GPE
# Trinidad GPE
# Tobago GPE
# United Arab Emirates GPE
# OECD 2022 ORG
# 18 CARDINAL
# ODA Recipients ORG
# Belarus GPE
# Kosovo GPE
# Montserrat
# Saint Helena
#
# Republic of Türkiye
#  PERSON
# Tokelau GPE
# Ukraine GPE
# Wallis and Futuna
#
# Table A.6 GPE
# Australia GPE
# Austria GPE
# Belgium GPE
# Bulgaria GPE
# Canada GPE
# Croatia GPE
# Notes PRODUCT
# Czech Republic GPE
# Denmark GPE
# European Union
# Finland ORG
# France GPE
# Germany GPE
# Greece GPE
# Hungary GPE
# Iceland GPE
# Ireland GPE
# Italy GPE
# Japan GPE
# Latvia GPE
# Liechtenstein GPE
# Lithuania GPE
# Luxembourg GPE
# Malta GPE
# Monaco GPE
# Netherlands GPE
# New Zealand GPE
# Norway GPE
# Poland GPE
# Portugal GPE
# Romania GPE
# Slovak Republic
#  GPE
# Slovenia GPE
# Spain GPE
# Sweden GPE
# Switzerland GPE
# United Kingdom GPE
# United States GPE
# the Republic of Türkiye GPE
# Turkish NORP
# Greek Cypriot NORP
# The Republic of Türkiye GPE
# the Turkish Republic GPE
# Northern Cyprus LOC
# the United Nations ORG
# the Republic of Türkiye GPE
# European Union ORG
# States GPE
# OECD ORG
# the European Union ORG
# The Republic of Cyprus GPE
# the United Nations ORG
# the Republic of Türkiye GPE
# the Government of the Republic of Cyprus ORG
# M49 ORG
# the United Nations ORG
# UNSD ORG
# 2020[15 CARDINAL
# DAC ORG
# OECD ORG
# 2020[16 CARDINAL
# UN ORG
# Central Asia LOC
# post-soviet NORP
# Asia LOC
# Russia GPE
# Armenia GPE
# Azerbaijan GPE
# Georgia GPE
# Kazakhstan GPE
# Kyrgyzstan GPE
# Tajikistan GPE
# Turkmenistan GPE
# Uzbekistan GPE
# Western Asia LOC
# the Middle East LOC
# post-soviet NORP
# Armenia GPE
# Azerbaijan GPE
# Georgia GPE
# Central Asia LOC
# Sudan GPE
# Eastern Africa GPE
# North Africa GPE
# DAC ORG
# Table A.7 GPE
# OECD ORG
# 2022 CARDINAL
# 19 CARDINAL
# Africa LOC
# Asia LOC
# Europe LOC
# Algeria GPE
# Angola GPE
# Benin GPE
# Botswana GPE
# Burkina Faso PERSON
# Burundi GPE
# Cabo Verde PERSON
# Cameroon ORG
# Central African Republic GPE
# Chad GPE
# Comoros GPE
# Congo GPE
# Côte d’Ivoire ORG
# the Democratic Republic of the GPE
# Congo GPE
# Djibouti GPE
# Equatorial Guinea GPE
# Egypt GPE
# Eritrea GPE
# Eswatini ORG
# Ethiopia GPE
# Gabon GPE
# Gambia GPE
# Ghana GPE
# Guinea GPE
# Guinea-Bissau FAC
# Kenya GPE
# Lesotho GPE
# Liberia GPE
# Libya GPE
# Madagascar GPE
# Malawi PERSON
# Mali PERSON
# Mauritania GPE
# Mauritius ORG
# Morocco GPE
# Mozambique GPE
# Namibia GPE
# Niger GPE
# Nigeria GPE
# Rwanda GPE
# Saint Helena GPE
# Sao Tome GPE
# Principe, Senegal, Seychelles WORK_OF_ART
# Sierra Leone ORG
# Somalia GPE
# South Africa GPE
# South Sudan GPE
# Sudan GPE
# Tanzania GPE
# Togo GPE
# Tunisia GPE
# Uganda GPE
# Zambia GPE
# Zimbabwe GPE
# Afghanistan GPE
# Armenia GPE
# Azerbaijan GPE
# Bahrain GPE
# Bangladesh GPE
# Bhutan GPE
# Brunei Darussalam GPE
# Cambodia GPE
# China GPE
# Democratic NORP
# Korea GPE
# Georgia GPE
# India GPE
# Indonesia GPE
# Iran GPE
# Iraq GPE
# Israel GPE
# Jordan GPE
# Kazakhstan GPE
# Korea GPE
# Kuwait GPE
# Kyrgyzstan GPE
# Lao People’s Democratic Republic ORG
# Lebanon GPE
# Malaysia GPE
# Maldives GPE
# Mongolia GPE
# Myanmar GPE
# Nepal GPE
# Oman GPE
# Pakistan GPE
# Philippines GPE
# Republic of Türkiye GPE
# Qatar GPE
# Saudi Arabia GPE
# Singapore GPE
# Sri Lanka GPE
# Syrian NORP
# Tajikistan NORP
# Thailand GPE
# Timor-Leste GPE
# Turkmenistan GPE
# United Arab Emirates GPE
# Uzbekistan GPE
# Viet Nam GPE
# West Bank GPE
# Gaza Strip GPE
# Yemen GPE
# Albania GPE
# Andorra GPE
# Belarus GPE
# Bosnia and Herzegovina GPE
# Kosovo GPE
# Moldova GPE
# Montenegro GPE
# North Macedonia GPE
# San Marino GPE
# Serbia GPE
# Ukraine GPE
# Antigua GPE
# Barbuda GPE
# Argentina GPE
# Bahamas GPE
# Barbados GPE
# Belize GPE
# Bolivia GPE
# Brazil GPE
# Chile GPE
# Colombia GPE
# Costa Rica GPE
# Cuba GPE
# Dominica GPE
# Dominican Republic GPE
# Ecuador GPE
# El Salvador GPE
# Grenada GPE
# Guatemala GPE
# Guyana GPE
# Haiti GPE
# Honduras GPE
# Jamaica GPE
# Mexico GPE
# Montserrat GPE
# Nicaragua GPE
# Panama GPE
# Paraguay ORG
# Peru GPE
# Saint Kitts GPE
# Nevis GPE
# Saint Lucia PERSON
# Saint Vincent PERSON
# Grenadines ORG
# Suriname GPE
# Trinidad GPE
# Tobago GPE
# Uruguay GPE
# Venezuela GPE
# Cook Islands GPE
# Fiji GPE
# Kiribati GPE
# Marshall Islands ORG
# Micronesia GPE
# Nauru GPE
# Niue GPE
# Palau GPE
# Papua New Guinea GPE
# Samoa ORG
# Solomon
# Islands PERSON
# Tokelau GPE
# Tonga GPE
# Tuvalu GPE
# Vanuatu GPE
# Wallis and Futuna
#
# Source GPE
# UNSD ORG
# 2020[15 CARDINAL
# OECD ORG
# 2020[16 CARDINAL
# OECD ORG
# 2022 DATE
# 20 CARDINAL
# OECD ORG
# 2021 DATE
# OECD ORG
# 2021 DATE
# 2019 CARDINAL
# the USD 100 Billion Goal LAW
# OECD ORG
# Publishing GPE
# Paris GPE
# https://doi.org/10.1787/03590fb7-en PERSON
# OECD ORG
# 2021 DATE
# Converged Statistical Reporting Directives ORG
# Annual DATE
# OECD ORG
# 2020 DATE
# OECD ORG
# 2020 DATE
# 2013-18 DATE
# the USD 100 Billion Goal LAW
# OECD Publishing ORG
# Paris GPE
# OECD ORG
# 2020 DATE
# DAC ORG
# OECD ORG
# 2020 DATE
# OECD ORG
# 2020 DATE
# 2020 DATE
# OECD Publishing ORG
# Paris GPE
# OECD ORG
# 2019 DATE
# 2013-17 DATE
# the USD 100 Billion Goal LAW
# OECD Publishing ORG
# Paris GPE
# 2015 DATE
# OECD-CPI Report ORG
# UNFCCC GPE
# 2018 DATE
# Article 13 LAW
# the Paris
# Agreement EVENT
# Bonn GPE
# UNFCCC ORG
# 2018 DATE
# UNFCCC ORG
# 9 CARDINAL
# 5 CARDINAL
# 10 CARDINAL
# 8 CARDINAL
# 6 CARDINAL
# 15 CARDINAL
# 12 CARDINAL
# 16 CARDINAL
# 11 CARDINAL
# 4 CARDINAL
# 13 CARDINAL
# OECD ORG
# 2022 DATE
# UNFCCC ORG
# 2015 DATE
# the Paris Agreement ORG
# UNFCCC Secretariat ORG
# Bonn GPE
# UNFCCC ORG
# 2010 DATE
# Hoc Working Group ORG
# Cooperative Action ORG
# Secretariat GPE
# Bonn GPE
# 27 June 2022 DATE
# UNFCCC ORG
# 2009 DATE
# Copenhagen Accord PRODUCT
# UNFCCC Secretariat GPE
# Bonn GPE
# 27 June 2022 DATE
# UNSD ORG
# 2020 DATE
# Standard ORG
# https://unstats.un.org/unsd/methodology/m49 PERSON
# 21 CARDINAL
# 3 CARDINAL
# 2 CARDINAL
# 1 CARDINAL
# 14 CARDINAL
# OECD ORG
# 2022 CARDINAL
